# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv(r"C:\geethanjaliexternship\nba_logreg.csv")

# %%
d.head()
# Out:
#               name  gp   min  pts  fgm  fga    fg  3p_made  3pa    3p  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    fta    ft  oreb  dreb  reb  ast  stl  blk  tov  target_5yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8          1.0
#
# [5 rows x 21 columns]

# %%
d.isnull().any()
# Out:
# name           False
# gp             False
# min            False
# pts            False
# fgm            False
# fga            False
# fg             False
# 3p_made        False
# 3pa            False
# 3p              True
# ftm            False
# fta            False
# ft             False
# oreb           False
# dreb           False
# reb            False
# ast            False
# stl            False
# blk            False
# tov            False
# target_5yrs    False
# dtype: bool

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 21 columns):
# name           1340 non-null object
# gp             1340 non-null int64
# min            1340 non-null float64
# pts            1340 non-null float64
# fgm            1340 non-null float64
# fga            1340 non-null float64
# fg             1340 non-null float64
# 3p_made        1340 non-null float64
# 3pa            1340 non-null float64
# 3p             1329 non-null float64
# ftm            1340 non-null float64
# fta            1340 non-null float64
# ft             1340 non-null float64
# oreb           1340 non-null float64
# dreb           1340 non-null float64
# reb            1340 non-null float64
# ast            1340 non-null float64
# stl            1340 non-null float64
# blk            1340 non-null float64
# tov            1340 non-null float64
# target_5yrs    1340 non-null float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 219.9+ KB

# %%
d["3p"].mean()
# Out:
# 19.308126410835207

# %%
d["3p"].fillna(d["3p"].mean(),inplace = True)

# %%
x=d.iloc[:,1:20].values
y=d.iloc[:,20].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test  = train_test_split(x,y , test_size = 0.2 , random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# %%
ann=Sequential()

# %%
ann.add(Dense(19,kernel_initializer = "random_uniform", activation ="relu"))

# %%
ann.add(Dense(38,kernel_initializer = "random_uniform", activation ="relu"))

# %%
ann.add(Dense(1,kernel_initializer = "random_uniform", activation ="sigmoid"))

# %%
ann.compile("adam","binary_crossentropy",metrics=["accuracy"])

# %%
ann.fit(x_train,y_train,batch_size=32,epochs=500)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 4s 5ms/step - loss: 0.6896 - accuracy: 0.6177
# Epoch 2/500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6447 - accuracy: 0.6218
# Epoch 3/500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5981 - accuracy: 0.6853
# Epoch 4/500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.7124
# Epoch 5/500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.7077
# Epoch 6/500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5580 - accuracy: 0.7085
# Epoch 7/500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.7071
# Epoch 8/500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5503 - accuracy: 0.7292
# Epoch 9/500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5689 - accuracy: 0.7103
# Epoch 10/500
# ...

# %%
ypred=ann.predict(x_test)

# %%
d.head(1)
# Out:
#              name  gp   min  pts  fgm  fga    fg  3p_made  3pa    3p  ...  \
# 0  Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
#
#    fta    ft  oreb  dreb  reb  ast  stl  blk  tov  target_5yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
#
# [1 rows x 21 columns]

# %%
yp=ann.predict(sc.transform([[36,274,7.4,2.6,7.6,34.7,0.5,2.1,25.0,1.6,2.3,69.9,0.7,3.4,4.1,1.9,0.1,0.4,1.3]]))

# %%
yp
# Out:
# array([[0.]], dtype=float32)

# %%
yp>0.5
# Out:
# array([[False]])

# %%
yp=ann.predict(sc.transform([[40,280,7.9,3.6,44.7,8.5,5.1,55.0,5.6,2.8,69.7,2.7,5.4,2.1,8.9,0.3,0.2,1.5,5.2]]))

# %%
yp>0.5
# Out:
# array([[ True]])
